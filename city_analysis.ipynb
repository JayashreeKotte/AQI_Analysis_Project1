# %%
# Import Dependencies
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd
import requests
import json
import hvplot.pandas

# Import the API key
from config import api_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Read in our csv file with city info and put it into a dataframe
file_path = Path("worldcities.csv")
city_df = pd.read_csv(file_path)

city_df
# Out:
#               city   city_ascii      lat       lng        country iso2 iso3  \
# 0            Tokyo        Tokyo  35.6850  139.7514          Japan   JP  JPN
# 1         New York     New York  40.6943  -73.9249  United States   US  USA
# 2      Mexico City  Mexico City  19.4424  -99.1310         Mexico   MX  MEX
# 3           Mumbai       Mumbai  19.0170   72.8570          India   IN  IND
# 4        São Paulo    Sao Paulo -23.5587  -46.6250         Brazil   BR  BRA
# ...            ...          ...      ...       ...            ...  ...  ...
# 15488  Timmiarmiut  Timmiarmiut  62.5333  -42.2167      Greenland   GL  GRL
# 15489  Cheremoshna  Cheremoshna  51.3894   30.0989        Ukraine   UA  UKR
# 15490    Ambarchik    Ambarchik  69.6510  162.3336         Russia   RU  RUS
# 15491      Nordvik      Nordvik  74.0165  111.5100         Russia   RU  RUS
# 15492      Ennadai      Ennadai  61.1333 -100.8833         Canada   CA  CAN
#
#                admin_name  capital  population          id
# 0                   Tōkyō  primary  35676000.0  1392685764
# 1                New York      NaN  19354922.0  1840034016
# 2        Ciudad de México  primary  19028000.0  1484247881
# 3             Mahārāshtra    admin  18978000.0  1356226629
# 4               São Paulo    admin  18845000.0  1076532519
# ...                   ...      ...         ...         ...
# 15488            Kujalleq      NaN        10.0  1304206491
# 15489   Kyyivs’ka Oblast’      NaN         0.0  1804043438
# 15490    Sakha (Yakutiya)      NaN         0.0  1643739159
# 15491  Krasnoyarskiy Kray      NaN         0.0  1643587468
# 15492             Nunavut      NaN         0.0  1124019423
#
# [15493 rows x 11 columns]

# %%
# Filter only for cities in the US with a population of 100,000 residents or more
usa_df = city_df.loc[(city_df["country"] == "United States") & (city_df["population"] >= 100000)]

usa_df = usa_df.rename(columns={"admin_name": "state"})
usa_df["population"] = usa_df["population"].astype("int64")

usa_df
# Out:
#              city   city_ascii      lat       lng        country iso2 iso3  \
# 1        New York     New York  40.6943  -73.9249  United States   US  USA
# 8     Los Angeles  Los Angeles  34.1139 -118.4068  United States   US  USA
# 24        Chicago      Chicago  41.8373  -87.6862  United States   US  USA
# 40          Miami        Miami  25.7839  -80.2102  United States   US  USA
# 42         Dallas       Dallas  32.7936  -96.7662  United States   US  USA
# ...           ...          ...      ...       ...            ...  ...  ...
# 3254      Holland      Holland  42.7677  -86.0984  United States   US  USA
# 3257    Vacaville    Vacaville  38.3590 -121.9680  United States   US  USA
# 3258        Logan        Logan  41.7400 -111.8419  United States   US  USA
# 3259        Allen        Allen  33.1088  -96.6735  United States   US  USA
# 3269     Longview     Longview  32.5192  -94.7622  United States   US  USA
#
#            state capital  population          id
# 1       New York     NaN    19354922  1840034016
# 8     California     NaN    12815475  1840020491
# 24      Illinois     NaN     8675982  1840000494
# 40       Florida     NaN     6381966  1840015149
# 42         Texas     NaN     5733259  1840019440
# ...          ...     ...         ...         ...
# 3254    Michigan     NaN      100885  1840002996
# 3257  California     NaN      100801  1840021498
# 3258        Utah     NaN      100774  1840020108
# 3259       Texas     NaN      100685  1840019396
# 3269       Texas     NaN      100196  1840020746
#
# [457 rows x 11 columns]

# %%
# Get a statistical overview of our columns
usa_df.describe()
# Out:
#               lat         lng    population            id
# count  457.000000  457.000000  4.570000e+02  4.570000e+02
# mean    36.937449  -96.143763  5.615246e+05  1.840016e+09
# std      5.290188   17.485529  1.402281e+06  1.149755e+04
# min     21.329400 -157.846000  1.001960e+05  1.840000e+09
# 25%     33.492800 -116.231200  1.326310e+05  1.840007e+09
# 50%     37.004700  -92.477800  1.996950e+05  1.840018e+09
# 75%     40.808800  -81.246000  3.897920e+05  1.840021e+09
# max     61.150800  -70.271500  1.935492e+07  1.840088e+09

# %%
# Ensure all columns have the proper data-types
usa_df.dtypes
# Out:
# city           object
# city_ascii     object
# lat           float64
# lng           float64
# country        object
# iso2           object
# iso3           object
# state          object
# capital        object
# population      int64
# id              int64
# dtype: object

# %%
# Add new Air Quality Index Level columns for each city in dataframe
usa_df["AQI"] = " "
usa_df["CO"] = " "
usa_df["NO"] = " "
usa_df["NO2"] = " "
usa_df["O3"] = " "
usa_df["SO2"] = " "
usa_df["PM2.5"] = " "
usa_df["PM10"] = " "
usa_df["NH3"] = " "

usa_df
# Out:
#              city   city_ascii      lat       lng        country iso2 iso3  \
# 1        New York     New York  40.6943  -73.9249  United States   US  USA
# 8     Los Angeles  Los Angeles  34.1139 -118.4068  United States   US  USA
# 24        Chicago      Chicago  41.8373  -87.6862  United States   US  USA
# 40          Miami        Miami  25.7839  -80.2102  United States   US  USA
# 42         Dallas       Dallas  32.7936  -96.7662  United States   US  USA
# ...           ...          ...      ...       ...            ...  ...  ...
# 3254      Holland      Holland  42.7677  -86.0984  United States   US  USA
# 3257    Vacaville    Vacaville  38.3590 -121.9680  United States   US  USA
# 3258        Logan        Logan  41.7400 -111.8419  United States   US  USA
# 3259        Allen        Allen  33.1088  -96.6735  United States   US  USA
# 3269     Longview     Longview  32.5192  -94.7622  United States   US  USA
#
#            state capital  population          id AQI CO NO NO2 O3 SO2 PM2.5  \
# 1       New York     NaN    19354922  1840034016
# 8     California     NaN    12815475  1840020491
# 24      Illinois     NaN     8675982  1840000494
# 40       Florida     NaN     6381966  1840015149
# 42         Texas     NaN     5733259  1840019440
# ...          ...     ...         ...         ...  .. .. ..  .. ..  ..   ...
# 3254    Michigan     NaN      100885  1840002996
# 3257  California     NaN      100801  1840021498
# 3258        Utah     NaN      100774  1840020108
# 3259       Texas     NaN      100685  1840019396
# 3269       Texas     NaN      100196  1840020746
#
#      PM10 NH3
# 1
# 8
# 24
# 40
# 42
# ...   ...  ..
# 3254
# 3257
# 3258
# 3259
# 3269
#
# [457 rows x 20 columns]

# %%
# Set base URL and params to search for current air pollution data
base_url = "http://api.openweathermap.org/data/2.5/air_pollution?"

params = {"appid":api_key}

# Print a message to follow up the air pollution search
print("Starting city air pollution details search:")

# Iterate through the usa_df dataframe
for index, row in usa_df.iterrows():
    
    # Get city name, latitude, and longitude values for each row in dataframe
    city = row["city"]
    lat = row["lat"]
    lng = row["lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    params["lat"] = lat
    params["lon"] = lng
    
    # Make an API request using params dictionary and store it into a json
    response = requests.get(base_url, params=params)
    data = response.json()
    
    # Drill down to get the values we are looking for in the json and store those values in our dataframe
    try:
        usa_df.loc[index, "AQI"] = data["list"][0]["main"]["aqi"]
        usa_df.loc[index, "CO"] = data["list"][0]["components"]["co"]
        usa_df.loc[index, "NO"] = data["list"][0]["components"]["no"]
        usa_df.loc[index, "NO2"] = data["list"][0]["components"]["no2"]
        usa_df.loc[index, "O3"] = data["list"][0]["components"]["o3"]
        usa_df.loc[index, "SO2"] = data["list"][0]["components"]["so2"]
        usa_df.loc[index, "PM2.5"] = data["list"][0]["components"]["pm2_5"]
        usa_df.loc[index, "PM10"] = data["list"][0]["components"]["pm10"]
        usa_df.loc[index, "NH3"] = data["list"][0]["components"]["nh3"]
        
        
    except Exception as e:
        # If city is not found, log the error.
        print(f"{e.args} not found for {usa_df.loc[index, 'city']}")
        
    print(f"Appending results for {city}")
# Out:
# Starting city air pollution details search:
# Appending results for New York
# Appending results for Los Angeles
# Appending results for Chicago
# Appending results for Miami
# Appending results for Dallas
# Appending results for Philadelphia
# Appending results for Houston
# Appending results for Washington
# Appending results for Atlanta
# Appending results for Boston
# Appending results for Phoenix
# Appending results for Seattle
# Appending results for San Francisco
# Appending results for Detroit
# Appending results for San Diego
# Appending results for Minneapolis
# Appending results for Tampa
# Appending results for Denver
# Appending results for Brooklyn
# Appending results for Queens
# Appending results for Baltimore
# Appending results for Riverside
# Appending results for St. Louis
# Appending results for Las Vegas
# Appending results for Portland
# Appending results for San Antonio
# Appending results for Sacramento
# Appending results for San Jose
# Appending results for Orlando
# Appending results for Cleveland
# Appending results for Pittsburgh
# Appending results for Cincinnati
# Appending results for Manhattan
# Appending results for Austin
# Appending results for Kansas City
# Appending results for Indianapolis
# Appending results for Columbus
# Appending results for Virginia Beach
# Appending results for Charlotte
# Appending results for Bronx
# Appending results for Milwaukee
# Appending results for Providence
# Appending results for Jacksonville
# Appending results for Salt Lake City
# Appending results for Nashville
# Appending results for Memphis
# Appending results for Richmond
# Appending results for New Orleans
# Appending results for Raleigh
# Appending results for Louisville
# Appending results for Oklahoma City
# Appending results for Bridgeport
# Appending results for Buffalo
# Appending results for Hartford
# Appending results for Fort Worth
# Appending results for Tucson
# Appending results for El Paso
# Appending results for Honolulu
# Appending results for Omaha
# Appending results for McAllen
# Appending results for Albuquerque
# Appending results for Birmingham
# Appending results for Dayton
# Appending results for Rochester
# Appending results for Sarasota
# Appending results for Fresno
# Appending results for Allentown
# Appending results for Tulsa
# Appending results for Concord
# Appending results for Cape Coral
# Appending results for Springfield
# Appending results for Colorado Springs
# Appending results for Charleston
# Appending results for Grand Rapids
# Appending results for Mission Viejo
# Appending results for Albany
# Appending results for Knoxville
# Appending results for Baton Rouge
# Appending results for Bakersfield
# Appending results for Ogden
# Appending results for New Haven
# Appending results for Columbia
# Appending results for Akron
# Appending results for Provo
# Appending results for Worcester
# Appending results for Mesa
# Appending results for Palm Bay
# Appending results for Toledo
# Appending results for Brookhaven
# Appending results for Murrieta
# Appending results for Wichita
# Appending results for Des Moines
# Appending results for Staten Island
# Appending results for Long Beach
# Appending results for Greenville
# Appending results for Little Rock
# Appending results for Harrisburg
# Appending results for Denton
# Appending results for Madison
# Appending results for Reno
# Appending results for Port St. Lucie
# Appending results for Oakland
# Appending results for Winston-Salem
# Appending results for Indio
# Appending results for Durham
# Appending results for Syracuse
# Appending results for Chattanooga
# Appending results for Lancaster
# Appending results for Spokane
# Appending results for Palm Coast
# Appending results for Arlington
# Appending results for Bonita Springs
# Appending results for Poughkeepsie
# Appending results for Stockton
# Appending results for Oxnard
# Appending results for Augusta
# Appending results for Scranton
# Appending results for Boise
# Appending results for Modesto
# Appending results for Kissimmee
# Appending results for Youngstown
# Appending results for Aurora
# Appending results for Anaheim
# Appending results for Lancaster
# Appending results for Victorville
# Appending results for Pensacola
# Appending results for Fayetteville
# Appending results for Corpus Christi
# Appending results for Jackson
# Appending results for Greensboro
# Appending results for Flint
# Appending results for Islip
# Appending results for Santa Ana
# Appending results for Fort Wayne
# Appending results for Ann Arbor
# Appending results for Fayetteville
# Appending results for Santa Rosa
# Appending results for Lansing
# Appending results for Mobile
# Appending results for Lexington
# Appending results for Huntsville
# Appending results for Santa Clarita
# Appending results for Asheville
# Appending results for St. Paul
# Appending results for Fort Collins
# Appending results for Antioch
# Appending results for Henderson
# Appending results for Oyster Bay
# Appending results for Trenton
# Appending results for Lakeland
# Appending results for Shreveport
# Appending results for Davenport
# Appending results for Springfield
# Appending results for Plano
# Appending results for Rockford
# Appending results for Newark
# Appending results for Lincoln
# Appending results for Round Lake Beach
# Appending results for South Bend
# Appending results for Savannah
# Appending results for Irvine
# Appending results for Canton
# Appending results for Jersey City
# Appending results for Chula Vista
# Appending results for Eugene
# Appending results for Reading
# Appending results for Lafayette
# Appending results for St. Petersburg
# Appending results for Lubbock
# Appending results for Peoria
# Appending results for Myrtle Beach
# Appending results for Laredo
# Appending results for Salem
# Appending results for Columbus
# Appending results for Montgomery
# Appending results for Chandler
# Appending results for Anchorage
# Appending results for Tallahassee
# Appending results for Concord
# Appending results for Scottsdale
# Appending results for Killeen
# Appending results for Glendale
# Appending results for Wilmington
# Appending results for Winter Haven
# Appending results for Norfolk
# Appending results for North Las Vegas
# Appending results for Gilbert
# Appending results for Atlantic City
# Appending results for Barnstable Town
# Appending results for Chesapeake
# Appending results for Irving
# Appending results for Hialeah
# Appending results for Garland
# Appending results for McKinney
# Appending results for Fremont
# Appending results for Visalia
# Appending results for York
# Appending results for Kennewick
# Appending results for Evansville
# Appending results for Paradise
# Appending results for Nashua
# Appending results for North Hempstead
# Appending results for Arlington
# Appending results for Brownsville
# Appending results for Appleton
# Appending results for Gulfport
# Appending results for Thousand Oaks
# Appending results for Avondale
# Appending results for San Bernardino
# Appending results for Bremerton
# Appending results for Roanoke
# Appending results for Hickory
# Appending results for Kalamazoo
# Appending results for Tacoma
# Appending results for Fontana
# Appending results for Green Bay
# Appending results for College Station
# Appending results for Moreno Valley
# Appending results for Amarillo
# Appending results for Portland
# Appending results for Fargo
# Appending results for Santa Barbara
# Appending results for Huntington
# Appending results for Norwich
# Appending results for Glendale
# Appending results for Yonkers
# Appending results for Huntington Beach
# Appending results for Aurora
# Appending results for Gainesville
# Appending results for Olympia
# Appending results for North Port
# Appending results for Spring Valley
# Appending results for Huntington
# Appending results for Deltona
# Appending results for Sunrise Manor
# Appending results for Grand Prairie
# Appending results for Salinas
# Appending results for Waterbury
# Appending results for Overland Park
# Appending results for Waco
# Appending results for Erie
# Appending results for Cedar Rapids
# Appending results for Hagerstown
# Appending results for Tempe
# Appending results for Spartanburg
# Appending results for Clarksville
# Appending results for Gastonia
# Appending results for Lorain
# Appending results for Sioux Falls
# Appending results for Fort Lauderdale
# Appending results for Newport News
# Appending results for High Point
# Appending results for Santa Cruz
# Appending results for Rancho Cucamonga
# Appending results for Frisco
# Appending results for Danbury
# Appending results for Hemet
# Appending results for Oceanside
# Appending results for Ontario
# Appending results for Vancouver
# Appending results for Garden Grove
# Appending results for Nampa
# Appending results for Vallejo
# Appending results for Elk Grove
# Appending results for Pembroke Pines
# Appending results for Medford
# Appending results for Peoria
# Appending results for Corona
# Appending results for Murfreesboro
# Appending results for Marysville
# Appending results for Cary
# Appending results for Fredericksburg
# Appending results for Ocala
# Appending results for Manchester
# Appending results for Hayward
# Appending results for Muskegon
# Appending results for Alexandria
# Appending results for Springfield
# Appending results for Lafayette
# Appending results for Port Arthur
# Appending results for Palmdale
# Appending results for Champaign
# Appending results for Gainesville
# Appending results for Enterprise
# Appending results for Frederick
# Appending results for Lakewood
# Appending results for Tuscaloosa
# Appending results for Sunnyvale
# Appending results for Lake Charles
# Appending results for Hollywood
# Appending results for Pasadena
# Appending results for Pomona
# Appending results for Kansas City
# Appending results for Macon
# Appending results for Escondido
# Appending results for Binghamton
# Appending results for Warner Robins
# Appending results for New Bedford
# Appending results for Topeka
# Appending results for Beaumont
# Appending results for Paterson
# Appending results for Joliet
# Appending results for Leesburg
# Appending results for Elkhart
# Appending results for Odessa
# Appending results for Naperville
# Appending results for Fairfield
# Appending results for Torrance
# Appending results for Panama City
# Appending results for Metairie
# Appending results for Bellevue
# Appending results for Midland
# Appending results for Merced
# Appending results for Mesquite
# Appending results for Houma
# Appending results for Charleston
# Appending results for Pasadena
# Appending results for Pueblo
# Appending results for Tyler
# Appending results for Orange
# Appending results for Fullerton
# Appending results for Miramar
# Appending results for Santa Maria
# Appending results for Athens
# Appending results for Columbia
# Appending results for Yuma
# Appending results for Olathe
# Appending results for Thornton
# Appending results for Harlingen
# Appending results for Grand Junction
# Appending results for West Valley City
# Appending results for Carrollton
# Appending results for Roseville
# Appending results for Warren
# Appending results for Bloomington
# Appending results for Hampton
# Appending results for Ramapo
# Appending results for Surprise
# Appending results for Las Cruces
# Appending results for Greeley
# Appending results for Yakima
# Appending results for Coral Springs
# Appending results for Sterling Heights
# Appending results for Mauldin
# Appending results for Racine
# Appending results for Stamford
# Appending results for Elizabeth
# Appending results for Kent
# Appending results for Greenville
# Appending results for Simi Valley
# Appending results for Burlington
# Appending results for Santa Clara
# Appending results for Johnson City
# Appending results for Boulder
# Appending results for Bellingham
# Appending results for Fort Smith
# Appending results for Amherst
# Appending results for Lynchburg
# Appending results for Kenosha
# Appending results for East Los Angeles
# Appending results for South Lyon
# Appending results for Round Rock
# Appending results for Berkeley
# Appending results for Billings
# Appending results for Redding
# Appending results for Yuba City
# Appending results for Duluth
# Appending results for Pearland
# Appending results for Leominster
# Appending results for Saginaw
# Appending results for Iowa City
# Appending results for Arvada
# Appending results for Seaside
# Appending results for Kingsport
# Appending results for Smithtown
# Appending results for Independence
# Appending results for Lehigh Acres
# Appending results for Richardson
# Appending results for Rochester
# Appending results for Gilroy
# Appending results for El Monte
# Appending results for Rock Hill
# Appending results for Clearwater
# Appending results for Monroe
# Appending results for Dover
# Appending results for Carlsbad
# Appending results for Norman
# Appending results for Abilene
# Appending results for Bloomington
# Appending results for Texas City
# Appending results for Temecula
# Appending results for Utica
# Appending results for St. Cloud
# Appending results for St. George
# Appending results for West Jordan
# Appending results for Costa Mesa
# Appending results for Miami Gardens
# Appending results for Cambridge
# Appending results for Brandon
# Appending results for Downey
# Appending results for Coeur d'Alene
# Appending results for Westminster
# Appending results for Elgin
# Appending results for El Centro
# Appending results for Waterloo
# Appending results for Lowell
# Appending results for Gresham
# Appending results for North Charleston
# Appending results for San Buenaventura
# Appending results for Inglewood
# Appending results for Pompano Beach
# Appending results for Centennial
# Appending results for West Palm Beach
# Appending results for Everett
# Appending results for Santa Fe
# Appending results for Richmond
# Appending results for Clovis
# Appending results for The Woodlands
# Appending results for Pottstown
# Appending results for Jacksonville
# Appending results for Broken Arrow
# Appending results for Burlington
# Appending results for West Covina
# Appending results for Turlock
# Appending results for Daly City
# Appending results for Eau Claire
# Appending results for Hillsboro
# Appending results for Sandy Springs
# Appending results for Sioux City
# Appending results for Chico
# Appending results for Norwalk
# Appending results for Salisbury
# Appending results for Jurupa Valley
# Appending results for Lewisville
# Appending results for Highlands Ranch
# Appending results for Davie
# Appending results for League City
# Appending results for Burbank
# Appending results for San Mateo
# Appending results for Spring Hill
# Appending results for El Cajon
# Appending results for Rialto
# Appending results for Bend
# Appending results for Columbia
# Appending results for Edison
# Appending results for Charlottesville
# Appending results for La Crosse
# Appending results for Temple
# Appending results for Woodbridge
# Appending results for Vista
# Appending results for Renton
# Appending results for Sparks
# Appending results for Holland
# Appending results for Vacaville
# Appending results for Logan
# Appending results for Allen
# Appending results for Longview

# %% [markdown]
# #####  Air Quality Index. Possible values: 1, 2, 3, 4, 5. Where 1 = Good, 2 = Fair, 3 = Moderate, 4 = Poor, 5 = Very Poor.

# %%
# Preview the updated dataframe and sort the results by AQI in descending order
usa_df.head(20).sort_values(by="AQI", ascending=False)
# Out:
#               city     city_ascii      lat       lng        country iso2 iso3  \
# 73         Phoenix        Phoenix  33.5722 -112.0891  United States   US  USA
# 47         Houston        Houston  29.7869  -95.3905  United States   US  USA
# 50      Washington     Washington  38.9047  -77.0163  United States   US  USA
# 61          Boston         Boston  42.3188  -71.0846  United States   US  USA
# 146       Brooklyn       Brooklyn  40.6501  -73.9496  United States   US  USA
# 105      San Diego      San Diego  32.8312 -117.1225  United States   US  USA
# 89   San Francisco  San Francisco  37.7562 -122.4430  United States   US  USA
# 87         Seattle        Seattle  47.6211 -122.3244  United States   US  USA
# 8      Los Angeles    Los Angeles  34.1139 -118.4068  United States   US  USA
# 1         New York       New York  40.6943  -73.9249  United States   US  USA
# 24         Chicago        Chicago  41.8373  -87.6862  United States   US  USA
# 175         Queens         Queens  40.7498  -73.7976  United States   US  USA
# 51         Atlanta        Atlanta  33.7627  -84.4225  United States   US  USA
# 44    Philadelphia   Philadelphia  40.0077  -75.1339  United States   US  USA
# 42          Dallas         Dallas  32.7936  -96.7662  United States   US  USA
# 92         Detroit        Detroit  42.3834  -83.1024  United States   US  USA
# 40           Miami          Miami  25.7839  -80.2102  United States   US  USA
# 124    Minneapolis    Minneapolis  44.9635  -93.2678  United States   US  USA
# 131          Tampa          Tampa  27.9942  -82.4451  United States   US  USA
# 135         Denver         Denver  39.7621 -104.8759  United States   US  USA
#
#                     state  capital  population          id AQI      CO     NO  \
# 73                Arizona    admin     4081849  1840020568   3  787.74  24.36
# 47                  Texas      NaN     5446468  1840020925   3  634.19  14.53
# 50   District of Columbia  primary     5289420  1840006060   3  293.73      0
# 61          Massachusetts    admin     4637537  1840000455   2  236.99      0
# 146              New York      NaN     2629150  1840034030   2  400.54    2.6
# 105            California      NaN     3210314  1840021990   2  594.14    0.3
# 89             California      NaN     3603761  1840021543   2  243.66      0
# 87             Washington      NaN     3643765  1840021117   2  600.82  20.12
# 8              California      NaN    12815475  1840020491   2  520.71   0.06
# 1                New York      NaN    19354922  1840034016   2  400.54    2.6
# 24               Illinois      NaN     8675982  1840000494   2  447.27   2.54
# 175              New York      NaN     2333054  1840034002   2   467.3   4.08
# 51                Georgia    admin     5228750  1840013660   1  243.66      0
# 44           Pennsylvania      NaN     5637884  1840000673   1  280.38      0
# 42                  Texas      NaN     5733259  1840019440   1  257.02      0
# 92               Michigan      NaN     3522206  1840003971   1  323.77   0.07
# 40                Florida      NaN     6381966  1840015149   1  201.94      0
# 124             Minnesota      NaN     2926757  1840007830   1  270.37      0
# 131               Florida      NaN     2804240  1840015982   1  230.31      0
# 135              Colorado    admin     2787266  1840018789   1  357.15   1.73
#
#        NO2     O3   SO2  PM2.5   PM10   NH3
# 73   69.23      0  2.74     28  38.07  3.07
# 47   42.16   0.07  3.31  37.94  43.26  0.05
# 50    4.76  40.05  0.54  25.23  26.11  0.09
# 61    7.37  64.37  1.22   3.15   5.79  0.14
# 146  44.55   3.84  5.01   9.77  14.59  0.74
# 105  43.87   4.65  3.07   14.8  17.31  0.69
# 89    3.94  65.09  0.73   0.79   1.06  0.09
# 87   43.87      0  1.51  14.51  20.79  1.11
# 8    63.75  13.41  6.86  14.74  16.98  0.59
# 1    44.55   3.84  5.01   9.77  14.59  0.74
# 24   42.84   3.62   2.5  10.34  13.57   1.6
# 175  54.15   2.19  8.11  11.82   17.5  1.17
# 51     5.1  38.62  3.04   5.18   6.05  0.08
# 44   11.82  35.76  0.89   5.14   6.77  0.11
# 42    7.11  57.94  1.89   4.95   6.22  0.39
# 92   20.56  29.33  2.24   3.76    5.6  0.95
# 40    1.84  49.35  0.56      2   3.75  0.07
# 124   5.91  49.35  0.36   1.57   2.12  0.34
# 131   3.26  40.05  0.57   1.61   2.12  0.14
# 135  31.19   5.14     2   7.02   10.8  2.25

# %%
# Check which states in the US show the poorest AQI in descending order

state_aqi_df = usa_df.groupby("state")["AQI"].mean()

state_aqi_df.sort_values(ascending=False)
# Out:
# state
# District of Columbia    3.000000
# Hawaii                  2.000000
# Rhode Island            2.000000
# Vermont                 2.000000
# Nevada                  2.000000
# Alaska                  2.000000
# Utah                    1.857143
# Kansas                  1.800000
# Arizona                 1.750000
# Massachusetts           1.750000
# California              1.693182
# Maryland                1.600000
# Washington              1.571429
# Oregon                  1.571429
# Ohio                    1.555556
# Texas                   1.511628
# Virginia                1.416667
# New York                1.409091
# New Mexico              1.333333
# Idaho                   1.333333
# Colorado                1.214286
# Pennsylvania            1.200000
# Missouri                1.200000
# Connecticut             1.142857
# Louisiana               1.125000
# Georgia                 1.111111
# Illinois                1.090909
# Michigan                1.083333
# Florida                 1.055556
# Tennessee               1.000000
# South Dakota            1.000000
# South Carolina          1.000000
# West Virginia           1.000000
# Oklahoma                1.000000
# Alabama                 1.000000
# North Dakota            1.000000
# North Carolina          1.000000
# New Jersey              1.000000
# New Hampshire           1.000000
# Nebraska                1.000000
# Montana                 1.000000
# Mississippi             1.000000
# Minnesota               1.000000
# Maine                   1.000000
# Kentucky                1.000000
# Iowa                    1.000000
# Indiana                 1.000000
# Delaware                1.000000
# Arkansas                1.000000
# Wisconsin               1.000000
# Name: AQI, dtype: float64

# %%
usa_df.loc[usa_df["state"] == "New Jersey"]
# Out:
#                city     city_ascii      lat      lng        country iso2 iso3  \
# 1579        Trenton        Trenton  40.2236 -74.7641  United States   US  USA
# 1624         Newark         Newark  40.7245 -74.1725  United States   US  USA
# 1682    Jersey City    Jersey City  40.7161 -74.0683  United States   US  USA
# 1837  Atlantic City  Atlantic City  39.3797 -74.4527  United States   US  USA
# 2590       Paterson       Paterson  40.9147 -74.1624  United States   US  USA
# 2803      Elizabeth      Elizabeth  40.6657 -74.1912  United States   US  USA
# 3229         Edison         Edison  40.5360 -74.3697  United States   US  USA
# 3239     Woodbridge     Woodbridge  40.5611 -74.2943  United States   US  USA
#
#            state capital  population          id AQI      CO    NO    NO2  \
# 1579  New Jersey   admin      296869  1840001383   1  277.04     0  12.17
# 1624  New Jersey     NaN      285154  1840002791   1  333.79  0.12  26.39
# 1682  New Jersey     NaN      270753  1840003600   1  333.79  0.12  26.39
# 1837  New Jersey     NaN      241363  1840003798   1  233.65     0   2.27
# 2590  New Jersey     NaN      148678  1840000838   1  307.08  0.01  16.11
# 2803  New Jersey     NaN      130215  1840003613   1  333.79  0.12  26.39
# 3229  New Jersey     NaN      102304  1840081696   1  310.42  0.01  19.36
# 3239  New Jersey     NaN      101639  1840081695   1  310.42  0.01  19.36
#
#          O3   SO2 PM2.5   PM10   NH3
# 1579  36.48  0.72  4.81   6.38  0.05
# 1624   18.6  2.15  7.55  11.98  0.24
# 1682   18.6  2.15  7.55  11.98  0.24
# 1837  59.37  0.19  3.15   7.32  0.07
# 2590  27.54  0.86  6.57  10.24  0.09
# 2803   18.6  2.15  7.55  11.98  0.24
# 3229  26.82  1.33  6.39   9.35   0.1
# 3239  26.82  1.33  6.39   9.35   0.1

# %%
co_df = usa_df.head(20).sort_values(by="CO", ascending=False)

plt.bar(co_df["city"], co_df["CO"])
plt.title("Cities with Highest CO levels")
plt.ylabel("Concentration of CO")
plt.xticks(rotation = 90)
plt.show()

# %%
x = usa_df["CO"]
y = usa_df["AQI"]

plt.scatter(x, y, edgecolors="black")

# Incorporate the other graph properties
plt.title("Carbon Monoxide Levels vs. AQI")
plt.xlabel("Carbon Monoxide (CO)")
plt.ylabel("Air Quality Index")

plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %%
# Build scatter plot for 
x = usa_df["population"]
y = usa_df["CO"]

plt.scatter(x, y, edgecolors="black")

# Incorporate the other graph properties
plt.title("Population vs. Carbon Monoxide Levels")
plt.xlabel("Population")
plt.ylabel("Carbon Monoxide (CO)")

plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %%
x = usa_df["lat"]
y = usa_df["AQI"]

plt.scatter(x, y, edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. AQI")
plt.xlabel("Latitude")
plt.ylabel("Air Quality Index")

plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = usa_df.hvplot.points("lng", "lat",  geo = True, tiles = "OSM", color = "city",
                                  hover_cols = ["city", "state", "population", "AQI"], frame_width=700, frame_height=500)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [lng,lat]   (city,state,population,AQI)
